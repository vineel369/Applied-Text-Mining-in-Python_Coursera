# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-text-mining/resources/d9pwm) course resource._
#
# ---

# %% [markdown]
# # Assignment 2 - Introduction to NLTK
#
# In part 1 of this assignment you will use nltk to explore the Herman Melville novel Moby Dick. Then in part 2 you will create a spelling recommender function that uses nltk to find words similar to the misspelling.

# %% [markdown]
# ## Part 1 - Analyzing Moby Dick

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/jovyan/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/jovyan/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/jovyan/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/jovyan/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/jovyan/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/jovyan/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# ...

# %%
import nltk
import pandas as pd
import numpy as np

# If you would like to work with the raw text you can use 'moby_raw'
with open('moby.txt', 'r') as f:
    moby_raw = f.read()
    
# If you would like to work with the novel in nltk.Text format you can use 'text1'
moby_tokens = nltk.word_tokenize(moby_raw)
text1 = nltk.Text(moby_tokens)

# %%
moby_tokens[:10]
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.']

# %%
len(text1[:2])
# Out:
# 2

# %% [markdown]
# ### Example 1
#
# How many tokens (words and punctuation symbols) are in text1?
#
# *This function should return an integer.*

# %%
def example_one():
    
    return len(nltk.word_tokenize(moby_raw)) # or alternatively len(text1)

example_one()
# Out:
# 254989

# %% [markdown]
# ### Example 2
#
# How many unique tokens (unique words and punctuation) does text1 have?
#
# *This function should return an integer.*

# %%
def example_two():
    
    return len(set(nltk.word_tokenize(moby_raw))) # or alternatively len(set(text1))

example_two()
# Out:
# 20755

# %% [markdown]
# ### Example 3
#
# After lemmatizing the verbs, how many unique tokens does text1 have?
#
# *This function should return an integer.*

# %%
from nltk.stem import WordNetLemmatizer

def example_three():

    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(w,'v') for w in text1]

    return len(set(lemmatized))

example_three()
# Out:
# 16900

# %% [markdown]
# ### Question 1
#
# What is the lexical diversity of the given text input? (i.e. ratio of unique tokens to the total number of tokens)
#
# *This function should return a float.*

# %%
def answer_one():
    
    unique_tokens_len = len(set(nltk.word_tokenize(moby_raw))) # or alternatively len(set(text1))
    total_tokens_len = len(nltk.word_tokenize(moby_raw)) # # or alternatively len(text1)
    
    return unique_tokens_len/total_tokens_len

answer_one()
# Out:
# 0.08139566804842562

# %% [markdown]
# ### Question 2
#
# What percentage of tokens is 'whale'or 'Whale'?
#
# *This function should return a float.*

# %%
from nltk.probability import FreqDist
dist_freq = FreqDist(text1) #FreqDist(moby_tokens)
len(dist_freq)
# Out:
# 20755

# %%
total_tokens_len = len(nltk.word_tokenize(moby_raw)) # # or alternatively len(text1)

# %%
def answer_two():
    
    return ((dist_freq['whale']+dist_freq['Whale']) / total_tokens_len)*100

answer_two()
# Out:
# 0.4125668166077752

# %% [markdown]
# ### Question 3
#
# What are the 20 most frequently occurring (unique) tokens in the text? What is their frequency?
#
# *This function should return a list of 20 tuples where each tuple is of the form `(token, frequency)`. The list should be sorted in descending order of frequency.*

# %%
def answer_three():
    
    sorted_list = sorted(dist_freq.items() , key = lambda item: item[1], reverse = True) # it is a list of tuples having key & values
    
    return sorted_list[:20]

answer_three()
# Out:
# [(',', 19204),
#  ('the', 13715),
#  ('.', 7308),
#  ('of', 6513),
#  ('and', 6010),
#  ('a', 4545),
#  ('to', 4515),
#  (';', 4173),
#  ('in', 3908),
#  ('that', 2978),
#  ('his', 2459),
#  ('it', 2196),
#  ('I', 2097),
#  ('!', 1767),
#  ('is', 1722),
#  ('--', 1713),
#  ('with', 1659),
#  ('he', 1658),
#  ('was', 1639),
#  ('as', 1620)]

# %% [markdown]
# ### Question 4
#
# What tokens have a length of greater than 5 and frequency of more than 150?
#
# *This function should return an alphabetically sorted list of the tokens that match the above constraints. To sort your list, use `sorted()`*

# %%
def answer_four():
    
    vocab1 = dist_freq.keys()
    tokens_list = [word for word in vocab1 if len(word) > 5 and dist_freq[word] > 150]
    
    return sorted(tokens_list)

answer_four()
# Out:
# ['Captain',
#  'Pequod',
#  'Queequeg',
#  'Starbuck',
#  'almost',
#  'before',
#  'himself',
#  'little',
#  'seemed',
#  'should',
#  'though',
#  'through',
#  'whales',
#  'without']

# %% [markdown]
# ### Question 5
#
# Find the longest word in text1 and that word's length.
#
# *This function should return a tuple `(longest_word, length)`.*

# %%
def answer_five():
    vocab = list(dist_freq.keys())
    word_lengths = [len(w) for w in vocab]
    word_max_length = vocab[word_lengths.index(max(word_lengths))]
    return (word_max_length, max(word_lengths))

answer_five()
# Out:
# ("twelve-o'clock-at-night", 23)

# %% [markdown]
# ### Question 6
#
# What unique words have a frequency of more than 2000? What is their frequency?
#
# "Hint:  you may want to use `isalpha()` to check if the token is a word and not punctuation."
#
# *This function should return a list of tuples of the form `(frequency, word)` sorted in descending order of frequency.*

# %%
def answer_six():
    
    unique_tokens_list = [(v,k) for k,v in dist_freq.items() if k.isalpha() and v > 2000]
    
    return sorted(unique_tokens_list, reverse = True)

answer_six()
# Out:
# [(13715, 'the'),
#  (6513, 'of'),
#  (6010, 'and'),
#  (4545, 'a'),
#  (4515, 'to'),
#  (3908, 'in'),
#  (2978, 'that'),
#  (2459, 'his'),
#  (2196, 'it'),
#  (2097, 'I')]

# %% [markdown]
# ### Question 7
#
# What is the average number of tokens per sentence?
#
# *This function should return a float.*

# %%
sentences = nltk.sent_tokenize(moby_raw)
sentences_tot = len(sentences)
sentences_tot
# Out:
# 9852

# %%
def answer_seven():
    
    sent_tokens = [ len(nltk.word_tokenize(sent)) for sent in sentences ]
    
    
    return sum(sent_tokens)/len(sent_tokens)

answer_seven()
# Out:
# 25.881952902963864

# %% [markdown]
# ### Question 8
#
# What are the 5 most frequent parts of speech in this text? What is their frequency?
#
# *This function should return a list of tuples of the form `(part_of_speech, frequency)` sorted in descending order of frequency.*

# %%
from collections import Counter
def answer_eight():
    
    pos_tag_freq = Counter([tag for word,tag in nltk.pos_tag(moby_tokens)])
    sorted_tags = sorted(pos_tag_freq.items() , key = lambda item:item[1], reverse = True)
#     sort_output = [ elem for elem in sorted_tags if elem[0]!= ',']                
    
    return sorted_tags[:5]

answer_eight()
# Out:
# [('NN', 32730), ('IN', 28657), ('DT', 25867), (',', 19204), ('JJ', 17620)]

# %% [markdown]
# ## Part 2 - Spelling Recommender
#
# For this part of the assignment you will create three different spelling recommenders, that each take a list of misspelled words and recommends a correctly spelled word for every word in the list.
#
# For every misspelled word, the recommender should find find the word in `correct_spellings` that has the shortest distance*, and starts with the same letter as the misspelled word, and return that word as a recommendation.
#
# *Each of the three different recommenders will use a different distance measure (outlined below).
#
# Each of the recommenders should provide recommendations for the three default words provided: `['cormulent', 'incendenece', 'validrate']`.

# %%
from nltk.corpus import words

correct_spellings = words.words()

# %%
correct_spellings_lower = [word.lower() for word in correct_spellings]
correct_spellings_lower
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
# ...

# %% [markdown]
# ### Question 9
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Jaccard distance](https://en.wikipedia.org/wiki/Jaccard_index) on the trigrams of the two words.**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
def answer_nine(entries=['cormulent', 'incendenece', 'validrate']):
    
    final = []
    
    for elem in entries:
        
        dictionary_list = [words for words in correct_spellings_lower if words.startswith(elem[0]) and len(words) > 2] # select the words from dictionary which are > 2 char & words starting with entry element char
        distance_list = [(nltk.distance.jaccard_distance(set(nltk.ngrams(elem,n=3)), set(nltk.ngrams(word,n=3))),word)\
                         for word in dictionary_list]
        final.append(sorted(distance_list)[0][1])  # sort the list in ascending order, having the shortest distance are on top
    
    return final
    
answer_nine()
# Out:
# ['corpulent', 'indecence', 'validate']

# %% [markdown]
# ### Question 10
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Jaccard distance](https://en.wikipedia.org/wiki/Jaccard_index) on the 4-grams of the two words.**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
def answer_ten(entries=['cormulent', 'incendenece', 'validrate']):
    final = []
    
    for elem in entries:
        
        dictionary_list = [words for words in correct_spellings_lower if words.startswith(elem[0]) and len(words) > 3] # select the words from dictionary which are > 3 char & words starting with entry element char
        distance_list = [(nltk.distance.jaccard_distance(set(nltk.ngrams(elem,n=4)), set(nltk.ngrams(word,n=4))),word)\
                         for word in dictionary_list]
        final.append(sorted(distance_list)[0][1]) #sort the list in ascending order, having the shortest distance are on top
    
    return final
    
answer_ten()
# Out:
# ['cormus', 'incendiary', 'valid']

# %% [markdown]
# ### Question 11
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Edit distance on the two words with transpositions.](https://en.wikipedia.org/wiki/Damerau%E2%80%93Levenshtein_distance)**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
def answer_eleven(entries=['cormulent', 'incendenece', 'validrate']):
    final = []
    
    for elem in entries:
        
        dictionary_list = [words for words in correct_spellings_lower if words.startswith(elem[0])] # select the words from dictionary which are > 3 char & words starting with entry element char
        distance_list = [(nltk.edit_distance(elem, word),word) for word in dictionary_list]
        final.append(sorted(distance_list)[0][1]) #sort the list in ascending order, having the shortest distance are on top
    
    return final
    
answer_eleven()
# Out:
# ['corpulent', 'intendence', 'validate']
